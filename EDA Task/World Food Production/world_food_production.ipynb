# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
world_food_production_df = pd.read_csv('world_food_production.csv')
world_food_production_df.head()
# Out:
#         Entity  Year  Maize Production (tonnes)  Rice  Production ( tonnes)  \
# 0  Afghanistan  1961                   700000.0                    319000.0
# 1  Afghanistan  1962                   700000.0                    319000.0
# 2  Afghanistan  1963                   713000.0                    319000.0
# 3  Afghanistan  1964                   720000.0                    380000.0
# 4  Afghanistan  1965                   720000.0                    380000.0
#
#    Yams  Production (tonnes)  Wheat Production (tonnes)  \
# 0                  7467702.0                  2279000.0
# 1                  7420515.0                  2279000.0
# 2                  8479074.0                  1947000.0
# 3                  9113779.0                  2230000.0
# 4                 10067913.0                  2282000.0
#
#    Tomatoes Production (tonnes)  Tea  Production ( tonnes )  \
# 0                     1873812.0                     56315.0
# ...

# %%
world_food_production_df.columns
# Out:
# Index(['Entity', 'Year', 'Maize Production (tonnes)',
#        'Rice  Production ( tonnes)', 'Yams  Production (tonnes)',
#        'Wheat Production (tonnes)', 'Tomatoes Production (tonnes)',
#        'Tea  Production ( tonnes )', 'Sweet potatoes  Production (tonnes)',
#        'Sunflower seed  Production (tonnes)', 'Sugar cane Production (tonnes)',
#        'Soybeans  Production (tonnes)', 'Rye  Production (tonnes)',
#        'Potatoes  Production (tonnes)', 'Oranges  Production (tonnes)',
#        'Peas, dry Production ( tonnes)', 'Palm oil  Production (tonnes)',
#        'Grapes  Production (tonnes)', 'Coffee, green Production ( tonnes)',
#        'Cocoa beans Production (tonnes)', 'Meat, chicken  Production (tonnes)',
#        'Bananas  Production ( tonnes)', 'Avocados Production (tonnes)',
#        'Apples Production (tonnes)'],
#       dtype='object')

# %%
world_food_production_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11912 entries, 0 to 11911
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Entity                               11912 non-null  object
#  1   Year                                 11912 non-null  int64
#  2   Maize Production (tonnes)            11912 non-null  float64
#  3   Rice  Production ( tonnes)           11912 non-null  float64
#  4   Yams  Production (tonnes)            11912 non-null  float64
#  5   Wheat Production (tonnes)            11912 non-null  float64
#  6   Tomatoes Production (tonnes)         11912 non-null  float64
#  7   Tea  Production ( tonnes )           11912 non-null  float64
#  8   Sweet potatoes  Production (tonnes)  11912 non-null  float64
#  9   Sunflower seed  Production (tonnes)  11912 non-null  float64
#  10  Sugar cane Production (tonnes)       11912 non-null  float64
# ...

# %%
world_food_production_df.isnull().sum()
# Out:
# Entity                                 0
# Year                                   0
# Maize Production (tonnes)              0
# Rice  Production ( tonnes)             0
# Yams  Production (tonnes)              0
# Wheat Production (tonnes)              0
# Tomatoes Production (tonnes)           0
# Tea  Production ( tonnes )             0
# Sweet potatoes  Production (tonnes)    0
# Sunflower seed  Production (tonnes)    0
# Sugar cane Production (tonnes)         0
# Soybeans  Production (tonnes)          0
# Rye  Production (tonnes)               0
# Potatoes  Production (tonnes)          0
# Oranges  Production (tonnes)           0
# Peas, dry Production ( tonnes)         0
# Palm oil  Production (tonnes)          0
# Grapes  Production (tonnes)            0
# Coffee, green Production ( tonnes)     0
# Cocoa beans Production (tonnes)        0
# Meat, chicken  Production (tonnes)     0
# Bananas  Production ( tonnes)          0
# Avocados Production (tonnes)           0
# ...

# %%
world_food_production_df[world_food_production_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Entity, Year, Maize Production (tonnes), Rice  Production ( tonnes), Yams  Production (tonnes), Wheat Production (tonnes), Tomatoes Production (tonnes), Tea  Production ( tonnes ), Sweet potatoes  Production (tonnes), Sunflower seed  Production (tonnes), Sugar cane Production (tonnes), Soybeans  Production (tonnes), Rye  Production (tonnes), Potatoes  Production (tonnes), Oranges  Production (tonnes), Peas, dry Production ( tonnes), Palm oil  Production (tonnes), Grapes  Production (tonnes), Coffee, green Production ( tonnes), Cocoa beans Production (tonnes), Meat, chicken  Production (tonnes), Bananas  Production ( tonnes), Avocados Production (tonnes), Apples Production (tonnes)]
# Index: []
#
# [0 rows x 24 columns]

# %%
world_food_production_df.describe().T
# Out:
#                                        count          mean           std  \
# Year                                 11912.0  1.992115e+03  1.760609e+01
# Maize Production (tonnes)            11912.0  1.926434e+07  7.028022e+07
# Rice  Production ( tonnes)           11912.0  2.254542e+07  7.749779e+07
# Yams  Production (tonnes)            11912.0  2.744973e+06  8.787786e+06
# Wheat Production (tonnes)            11912.0  2.365684e+07  6.177899e+07
# Tomatoes Production (tonnes)         11912.0  3.238661e+06  1.146992e+07
# Tea  Production ( tonnes )           11912.0  1.350523e+05  2.544264e+05
# Sweet potatoes  Production (tonnes)  11912.0  5.021303e+06  2.001692e+07
# Sunflower seed  Production (tonnes)  11912.0  1.410297e+06  3.625725e+06
# Sugar cane Production (tonnes)       11912.0  5.218411e+07  1.527085e+08
# Soybeans  Production (tonnes)        11912.0  7.902080e+06  2.773782e+07
# Rye  Production (tonnes)             11912.0  1.898678e+06  4.547930e+06
# ...

# %%
world_food_production_df.shape
# Out:
# (11912, 24)

# %%
print("number of countries: ",len(pd.unique(world_food_production_df['Entity'])))
pd.unique(world_food_production_df['Entity'])
# Out:
# number of countries:  226
# array(['Afghanistan', 'Africa', 'Africa (FAO)', 'Albania', 'Algeria',
#        'Americas (FAO)', 'Angola', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Asia', 'Asia (FAO)', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belgium-Luxembourg (FAO)', 'Belize', 'Benin', 'Bhutan',
#        'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Cape Verde', 'Caribbean (FAO)',
#        'Central African Republic', 'Central America (FAO)',
#        'Central Asia (FAO)', 'Chad', 'Chile', 'China', 'China (FAO)',
#        'Colombia', 'Comoros', 'Congo', 'Costa Rica', "Cote d'Ivoire",
#        'Croatia', 'Cuba', 'Czechia', 'Czechoslovakia',
#        'Democratic Republic of Congo', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'East Timor', 'Eastern Africa (FAO)',
# ...

# %%
world_food_production_df.groupby(['Entity']).first()
# Out:
#               Year  Maize Production (tonnes)  Rice  Production ( tonnes)  \
# Entity
# Afghanistan   1961                   700000.0                3.190000e+05
# Africa        1961                 16140043.0                4.307909e+06
# Africa (FAO)  1961                 16147243.0                4.309840e+06
# Albania       1961                   154104.0                4.603000e+03
# Algeria       1961                     5689.0                9.512000e+03
# ...            ...                        ...                         ...
# World         1961                205027250.0                2.158892e+07
# Yemen         1961                    12200.0                5.202360e+06
# Yugoslavia    1961                  4554000.0                2.063790e+06
# Zambia        1961                   660000.0                2.112268e+05
# Zimbabwe      1961                  1014000.0                3.764522e+05
#
#               Yams  Production (tonnes)  Wheat Production (tonnes)  \
# ...

# %%
aggregations = {}
numerical_columns = world_food_production_df.select_dtypes(include=['number']).columns.drop(labels=['Year']).to_numpy()
for col in numerical_columns:
    aggregations[col] = 'sum'
    
country_production = world_food_production_df.groupby(['Entity'], as_index=False).agg(aggregations)

country_production.head()
# Out:
#          Entity  Maize Production (tonnes)  Rice  Production ( tonnes)  \
# 0   Afghanistan               2.992980e+07                2.457988e+07
# 1        Africa               2.555105e+09                9.688623e+08
# 2  Africa (FAO)               2.557080e+09                9.692610e+08
# 3       Albania               1.619860e+07                3.498600e+05
# 4       Algeria               1.696285e+05                1.048863e+05
#
#    Yams  Production (tonnes)  Wheat Production (tonnes)  \
# 0               1.867137e+09                175353720.0
# 1               1.873572e+09                917333250.0
# 2               5.449159e+07                932322017.0
# 3               5.442330e+03                 20553494.9
# 4               1.048905e+07                107095475.2
#
#    Tomatoes Production (tonnes)  Tea  Production ( tonnes )  \
# 0                  6.136439e+08                  10276735.0
# 1                  6.301866e+08                   3818459.0
# ...
